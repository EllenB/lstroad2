# %% [markdown]
# ## Aim
#
# In this code, the Land Surface Temperature data (LST) using band 10 at the ward level are merged with the road characteristics

# %%
from pathlib import Path

## import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import linregress, pearsonr
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Reading in the data

# %%
# Define the paths
BASE_DIR = Path.cwd().parent
print(BASE_DIR)

DATA_DIR = BASE_DIR / "data"
PROCESSED_DIR = DATA_DIR / "processed"
IMAGES_DIR = BASE_DIR / "images"
# Out:
# C:\Ellen\personal\projects\geospatial\lst_bang_chennai\lstroad

# %% [markdown]
# ### Land Surface Temperature

# %%
lst_path = PROCESSED_DIR /'lstband10summer_bang.csv'
print(lst_path)
# Out:
# C:\Ellen\personal\projects\geospatial\lst_bang_chennai\lstroad\data\processed\lstband10summer_bang.csv

# %%
df_lst_mean_summer = pd.read_csv(lst_path)

# %%
df_lst_mean_summer.head()
# Out:
#    system:index               ward_name       mean  ward_id
# 0             0    25 - Vinayaka Layout  39.324657       25
# 1             1            2 - Aerocity  38.621582        2
# 2             2   3 - Chowdeshwari ward  38.597490        3
# 3             3  15 - Ramamurthy Nagara  38.432678       15
# 4             4    58 - Nagashettyhalli  37.427218       58

# %%
print(f"The minimum temperature is {df_lst_mean_summer['mean'].min()}.")
print(f"The maximum temperature is {df_lst_mean_summer['mean'].max()}.")
# Out:
# The minimum temperature is 35.593766695678646.
# The maximum temperature is 42.37974275787706.

# %% [markdown]
# ### Road density

# %%
road_density_path = PROCESSED_DIR /'results_bangalore_all_roads.csv'
df_road_density = pd.read_csv(road_density_path)

# %%
df_road_density.head()
# Out:
#    Unnamed: 0  ward_id               ward_name Corporatio  street_length  \
# 0           0       25    25 - Vinayaka Layout       West   75687.559355
# 1           1        2            2 - Aerocity      North  124800.280922
# 2           2        3   3 - Chowdeshwari ward      North  102396.516478
# 3           3       15  15 - Ramamurthy Nagara       East   22700.859701
# 4           4       58    58 - Nagashettyhalli      North   25813.225031
#
#    street_density          area
# 0    29390.911807  2.575203e+06
# 1    12164.886655  1.025906e+07
# 2    15924.039220  6.430310e+06
# 3    28293.603033  8.023319e+05
# 4    27016.836493  9.554496e+05

# %%
merged = pd.merge(df_lst_mean_summer, df_road_density, on='ward_name')
merged.head()
# Out:
#    system:index               ward_name       mean  ward_id_x  Unnamed: 0  \
# 0             0    25 - Vinayaka Layout  39.324657         25           0
# 1             1            2 - Aerocity  38.621582          2           1
# 2             2   3 - Chowdeshwari ward  38.597490          3           2
# 3             3  15 - Ramamurthy Nagara  38.432678         15           3
# 4             4    58 - Nagashettyhalli  37.427218         58           4
#
#    ward_id_y Corporatio  street_length  street_density          area
# 0         25       West   75687.559355    29390.911807  2.575203e+06
# 1          2      North  124800.280922    12164.886655  1.025906e+07
# 2          3      North  102396.516478    15924.039220  6.430310e+06
# 3         15       East   22700.859701    28293.603033  8.023319e+05
# 4         58      North   25813.225031    27016.836493  9.554496e+05

# %% [markdown]
# Only retain the relevant variables and rename:

# %%
merged = merged[['ward_name', 'mean', 'ward_id_x', 'Corporatio', 'street_length', 'street_density', 'area']]
merged.head()
# Out:
#                 ward_name       mean  ward_id_x Corporatio  street_length  \
# 0    25 - Vinayaka Layout  39.324657         25       West   75687.559355
# 1            2 - Aerocity  38.621582          2      North  124800.280922
# 2   3 - Chowdeshwari ward  38.597490          3      North  102396.516478
# 3  15 - Ramamurthy Nagara  38.432678         15       East   22700.859701
# 4    58 - Nagashettyhalli  37.427218         58      North   25813.225031
#
#    street_density          area
# 0    29390.911807  2.575203e+06
# 1    12164.886655  1.025906e+07
# 2    15924.039220  6.430310e+06
# 3    28293.603033  8.023319e+05
# 4    27016.836493  9.554496e+05

# %%
# Rename the columns
merged = merged.rename(columns={
    'ward_id_x': 'ward_id',
    'Corporatio': 'Corporation',
    'mean': 'mean_lst'
})
merged.head()
# Out:
#                 ward_name   mean_lst  ward_id Corporation  street_length  \
# 0    25 - Vinayaka Layout  39.324657       25        West   75687.559355
# 1            2 - Aerocity  38.621582        2       North  124800.280922
# 2   3 - Chowdeshwari ward  38.597490        3       North  102396.516478
# 3  15 - Ramamurthy Nagara  38.432678       15        East   22700.859701
# 4    58 - Nagashettyhalli  37.427218       58       North   25813.225031
#
#    street_density          area
# 0    29390.911807  2.575203e+06
# 1    12164.886655  1.025906e+07
# 2    15924.039220  6.430310e+06
# 3    28293.603033  8.023319e+05
# 4    27016.836493  9.554496e+05

# %%
print(f'The mininim street density is {merged["street_density"].min()} metres or {merged["street_density"].min()/1000} km per square km.')
print(f'The maximimum street density is {merged["street_density"].max()} metres or {merged["street_density"].max()/1000} km per square km.')
# Out:
# The mininim street density is 9898.12631486204 metres or 9.89812631486204 km per square km.
# The maximimum street density is 43516.131293869774 metres or 43.516131293869776 km per square km.

# %%
# index of min and max street density
idx_min = merged["street_density"].idxmin()
idx_max = merged["street_density"].idxmax()

# %%
# ward names
ward_min = merged.loc[idx_min, "ward_name"]
ward_max = merged.loc[idx_max, "ward_name"]

# %%
print(f' The ward with the minimum street density is {ward_min} and the maximum street density is {ward_max}.')
# Out:
#  The ward with the minimum street density is 27 - Vibhootipura and the maximum street density is 53 - Rayapuram.

# %% [markdown]
# #### Street density

# %%
fig_path = IMAGES_DIR / 'regression_bangalore_street_density.png'

# %%
# x and y
x = merged["street_density"]
y = merged["mean_lst"]

# linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# regression line
x_line = np.linspace(x.min(), x.max(), 100)
y_line = intercept + slope * x_line

# plot
plt.figure(figsize=(7, 6))
plt.scatter(x, y, alpha=0.6, label="Wards")
plt.plot(x_line, y_line, color="red", label="Linear fit")

plt.xlabel("street density")
plt.ylabel("Land Surface Temperature (LST)")
plt.title("LST versus street density")
plt.legend()

# annotation
plt.text(
    0.05, 0.98,
    f"$R^2$ = {r_value**2:.2f}\np = {p_value:.2e}",
    transform=plt.gca().transAxes,
    verticalalignment="top"
)

plt.text(
    0.05, 0.90,
    f"$LST = {intercept:.2f}{slope:.2f}\\,street density$",
    transform=plt.gca().transAxes,
    verticalalignment="top"
)
plt.savefig(fig_path, dpi=300, bbox_inches='tight')
plt.show()

# %%
p_value
# Out:
# np.float64(0.0663766638725885)

# %%
print(slope, intercept, r_value)
# Out:
# -1.7545412415225033e-05 39.34014447250534 -0.09567691387671325

# %%
pearsonr(merged['street_density'], merged['mean_lst'])
# Out:
# PearsonRResult(statistic=np.float64(-0.09567691387671327), pvalue=np.float64(0.06637666387258868))

# %%
#define response variable
y = merged['mean_lst']
#define predictor variables
x = merged['street_density']
#add constant to predictor variables
x = sm.add_constant(x)
#fit linear regression model
model = sm.OLS(y, x).fit()
#view model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               mean_lst   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     3.391
# Date:                Thu, 22 Jan 2026   Prob (F-statistic):             0.0664
# Time:                        23:32:20   Log-Likelihood:                -574.70
# No. Observations:                 369   AIC:                             1153.
# Df Residuals:                     367   BIC:                             1161.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             39.3401      0.268    146.878      0.000      38.813      39.867
# street_density -1.755e-05   9.53e-06     -1.841      0.066   -3.63e-05    1.19e-06
# ==============================================================================
# Omnibus:                        0.142   Durbin-Watson:                   1.948
# Prob(Omnibus):                  0.932   Jarque-Bera (JB):                0.247
# Skew:                           0.029   Prob(JB):                        0.884
# Kurtosis:                       2.888   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pearsonr(merged['street_density'], merged['mean_lst'])
# Out:
# PearsonRResult(statistic=np.float64(-0.09567691387671327), pvalue=np.float64(0.06637666387258868))

# %% [markdown]
# #### Straightness

# %%
straightness_path = PROCESSED_DIR /'results_bangalore_straightness_all_roads.csv'
df_straightness = pd.read_csv(straightness_path)

# %%
df_straightness.head()
# Out:
#    Unnamed: 0  ward_id               ward_name Corporatio  straightness
# 0           0       25    25 - Vinayaka Layout       West      0.722825
# 1           1        2            2 - Aerocity      North      0.644505
# 2           2        3   3 - Chowdeshwari ward      North      0.681202
# 3           3       15  15 - Ramamurthy Nagara       East      0.697888
# 4           4       58    58 - Nagashettyhalli      North      0.666402

# %%
merged = pd.merge(merged, df_straightness, on='ward_name')
merged.head()
# Out:
#                 ward_name   mean_lst  ward_id_x Corporation  street_length  \
# 0    25 - Vinayaka Layout  39.324657         25        West   75687.559355
# 1            2 - Aerocity  38.621582          2       North  124800.280922
# 2   3 - Chowdeshwari ward  38.597490          3       North  102396.516478
# 3  15 - Ramamurthy Nagara  38.432678         15        East   22700.859701
# 4    58 - Nagashettyhalli  37.427218         58       North   25813.225031
#
#    street_density          area  Unnamed: 0  ward_id_y Corporatio  \
# 0    29390.911807  2.575203e+06           0         25       West
# 1    12164.886655  1.025906e+07           1          2      North
# 2    15924.039220  6.430310e+06           2          3      North
# 3    28293.603033  8.023319e+05           3         15       East
# 4    27016.836493  9.554496e+05           4         58      North
#
#    straightness
# 0      0.722825
# 1      0.644505
# 2      0.681202
# 3      0.697888
# 4      0.666402

# %%
merged = merged[['ward_name', 'mean_lst', 'ward_id_x', 'Corporation', 'street_length', 'street_density', 'area', 'straightness']]
merged.head()
# Out:
#                 ward_name   mean_lst  ward_id_x Corporation  street_length  \
# 0    25 - Vinayaka Layout  39.324657         25        West   75687.559355
# 1            2 - Aerocity  38.621582          2       North  124800.280922
# 2   3 - Chowdeshwari ward  38.597490          3       North  102396.516478
# 3  15 - Ramamurthy Nagara  38.432678         15        East   22700.859701
# 4    58 - Nagashettyhalli  37.427218         58       North   25813.225031
#
#    street_density          area  straightness
# 0    29390.911807  2.575203e+06      0.722825
# 1    12164.886655  1.025906e+07      0.644505
# 2    15924.039220  6.430310e+06      0.681202
# 3    28293.603033  8.023319e+05      0.697888
# 4    27016.836493  9.554496e+05      0.666402

# %%
# x and y
x = merged["straightness"]
y = merged["mean_lst"]

# %%
fig_path = IMAGES_DIR / 'regression_bangalore_straightness.png'

# %%
# linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# regression line
x_line = np.linspace(x.min(), x.max(), 100)
y_line = intercept + slope * x_line

# plot
plt.figure(figsize=(7, 6))
plt.scatter(x, y, alpha=0.6, label="Wards")
plt.plot(x_line, y_line, color="red", label="Linear fit")

plt.xlabel("straightness")
plt.ylabel("Land Surface Temperature (LST)")
plt.title("LST versus straightness")
plt.legend()

# annotation

plt.text(
    0.05, 0.98,
    f"$R^2$ = {r_value**2:.2f}\np = {p_value:.2e}",
    transform=plt.gca().transAxes,
    verticalalignment="top"
)

plt.text(
    0.05, 0.90,
    f"$LST = {intercept:.2f}{slope:.2f}\\,straightness$",
    transform=plt.gca().transAxes,
    verticalalignment="top"
)
plt.savefig(fig_path, dpi=300, bbox_inches='tight')
plt.show()

# %%
#define response variable
y = merged['mean_lst']
#define predictor variables
x = merged['straightness']
#add constant to predictor variables
x = sm.add_constant(x)
#fit linear regression model
model = sm.OLS(y, x).fit()
#view model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               mean_lst   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     6.172
# Date:                Thu, 22 Jan 2026   Prob (F-statistic):             0.0134
# Time:                        23:32:25   Log-Likelihood:                -573.32
# No. Observations:                 369   AIC:                             1151.
# Df Residuals:                     367   BIC:                             1158.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           41.0158      0.870     47.141      0.000      39.305      42.727
# straightness    -3.1029      1.249     -2.484      0.013      -5.559      -0.647
# ==============================================================================
# Omnibus:                        0.480   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.786   Jarque-Bera (JB):                0.557
# Skew:                           0.082   Prob(JB):                        0.757
# Kurtosis:                       2.904   Cond. No.                         31.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pearsonr(merged['straightness'], merged['mean_lst'])
# Out:
# PearsonRResult(statistic=np.float64(-0.1286019447304938), pvalue=np.float64(0.013426367809896016))

# %% [markdown]
# #### Global closeness

# %%
global_closeness_path = PROCESSED_DIR /'results_bangalore_global_closeness_all_roads.csv'
df_global_closeness = pd.read_csv(global_closeness_path)

# %%
df_global_closeness.head()
# Out:
#    Unnamed: 0  ward_id               ward_name Corporatio  closeness
# 0           0       25    25 - Vinayaka Layout       West   0.000769
# 1           1        2            2 - Aerocity      North   0.000296
# 2           2        3   3 - Chowdeshwari ward      North   0.000380
# 3           3       15  15 - Ramamurthy Nagara       East   0.001307
# 4           4       58    58 - Nagashettyhalli      North   0.001277

# %%
merged = pd.merge(merged, df_global_closeness, on='ward_name')
merged.head()
# Out:
#                 ward_name   mean_lst  ward_id_x Corporation  street_length  \
# 0    25 - Vinayaka Layout  39.324657         25        West   75687.559355
# 1            2 - Aerocity  38.621582          2       North  124800.280922
# 2   3 - Chowdeshwari ward  38.597490          3       North  102396.516478
# 3  15 - Ramamurthy Nagara  38.432678         15        East   22700.859701
# 4    58 - Nagashettyhalli  37.427218         58       North   25813.225031
#
#    street_density          area  straightness  Unnamed: 0  ward_id Corporatio  \
# 0    29390.911807  2.575203e+06      0.722825           0       25       West
# 1    12164.886655  1.025906e+07      0.644505           1        2      North
# 2    15924.039220  6.430310e+06      0.681202           2        3      North
# 3    28293.603033  8.023319e+05      0.697888           3       15       East
# 4    27016.836493  9.554496e+05      0.666402           4       58      North
#
#    closeness
# 0   0.000769
# 1   0.000296
# 2   0.000380
# 3   0.001307
# 4   0.001277

# %%
merged = merged[['ward_name', 'mean_lst', 'ward_id_x', 'Corporation', 'street_length', 'street_density', 'area', 'straightness', 'closeness']]
merged.head()
# Out:
#                 ward_name   mean_lst  ward_id_x Corporation  street_length  \
# 0    25 - Vinayaka Layout  39.324657         25        West   75687.559355
# 1            2 - Aerocity  38.621582          2       North  124800.280922
# 2   3 - Chowdeshwari ward  38.597490          3       North  102396.516478
# 3  15 - Ramamurthy Nagara  38.432678         15        East   22700.859701
# 4    58 - Nagashettyhalli  37.427218         58       North   25813.225031
#
#    street_density          area  straightness  closeness
# 0    29390.911807  2.575203e+06      0.722825   0.000769
# 1    12164.886655  1.025906e+07      0.644505   0.000296
# 2    15924.039220  6.430310e+06      0.681202   0.000380
# 3    28293.603033  8.023319e+05      0.697888   0.001307
# 4    27016.836493  9.554496e+05      0.666402   0.001277

# %%
# Rename the columns
merged = merged.rename(columns={
    'ward_id_x': 'ward_id',
    'closeness': 'global_closeness'
})
merged.head()
# Out:
#                 ward_name   mean_lst  ward_id Corporation  street_length  \
# 0    25 - Vinayaka Layout  39.324657       25        West   75687.559355
# 1            2 - Aerocity  38.621582        2       North  124800.280922
# 2   3 - Chowdeshwari ward  38.597490        3       North  102396.516478
# 3  15 - Ramamurthy Nagara  38.432678       15        East   22700.859701
# 4    58 - Nagashettyhalli  37.427218       58       North   25813.225031
#
#    street_density          area  straightness  global_closeness
# 0    29390.911807  2.575203e+06      0.722825          0.000769
# 1    12164.886655  1.025906e+07      0.644505          0.000296
# 2    15924.039220  6.430310e+06      0.681202          0.000380
# 3    28293.603033  8.023319e+05      0.697888          0.001307
# 4    27016.836493  9.554496e+05      0.666402          0.001277

# %%
# x and y
x = merged["global_closeness"]
y = merged["mean_lst"]

# %%
# plot
# plt.figure(figsize=(7, 6))
# plt.scatter(x, y, alpha=0.6, label="Pixels")

# %%
fig_path = IMAGES_DIR / 'regression_bangalore_global_closeness.png'

# %%
# linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# regression line
x_line = np.linspace(x.min(), x.max(), 100)
y_line = intercept + slope * x_line

# plot
plt.figure(figsize=(7, 6))
plt.scatter(x, y, alpha=0.6, label="Wards")
plt.plot(x_line, y_line, color="red", label="Linear fit")

plt.xlabel("NDBI")
plt.ylabel("Land Surface Temperature (LST)")
plt.title("LST versus global closeness")
plt.legend()

# annotation

plt.text(
    0.05, 0.98,
    f"$R^2$ = {r_value**2:.2f}\np = {p_value:.2e}",
    transform=plt.gca().transAxes,
    verticalalignment="top"
)

plt.text(
    0.05, 0.90,
    f"$LST  = {intercept:.2f} + {slope:.2f}\\,global closeness$",
    transform=plt.gca().transAxes,
    verticalalignment="top"
)
plt.savefig(fig_path, dpi=300, bbox_inches='tight')
plt.show()

# %%
#define response variable
y = merged['mean_lst']
#define predictor variables
x = merged['global_closeness']
#add constant to predictor variables
x = sm.add_constant(x)
#fit linear regression model
model = sm.OLS(y, x).fit()
#view model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               mean_lst   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.8323
# Date:                Thu, 22 Jan 2026   Prob (F-statistic):              0.362
# Time:                        23:32:43   Log-Likelihood:                -575.98
# No. Observations:                 369   AIC:                             1156.
# Df Residuals:                     367   BIC:                             1164.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               38.7538      0.131    296.935      0.000      38.497      39.010
# global_closeness    98.6868    108.173      0.912      0.362    -114.029     311.403
# ==============================================================================
# Omnibus:                        1.618   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.445   Jarque-Bera (JB):                1.709
# Skew:                           0.140   Prob(JB):                        0.426
# Kurtosis:                       2.819   Cond. No.                     1.80e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.8e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pearsonr(merged['global_closeness'], merged['mean_lst'])
# Out:
# PearsonRResult(statistic=np.float64(0.047568205873754765), pvalue=np.float64(0.36220524251786607))

# %% [markdown]
# #### Local closeness

# %%
local_closeness_path = PROCESSED_DIR /'results_bangalore_local_closeness_all_roads.csv'
df_local_closeness = pd.read_csv(local_closeness_path)
df_local_closeness.head()
# Out:
#    Unnamed: 0  ward_id               ward_name Corporatio  closeness_local
# 0           0       25    25 - Vinayaka Layout       West         0.000321
# 1           1        2            2 - Aerocity      North         0.000146
# 2           2        3   3 - Chowdeshwari ward      North         0.000185
# 3           3       15  15 - Ramamurthy Nagara       East         0.000882
# 4           4       58    58 - Nagashettyhalli      North         0.000796

# %%
merged = pd.merge(merged, df_local_closeness, on='ward_name')
merged.head()
# Out:
#                 ward_name   mean_lst  ward_id_x Corporation  street_length  \
# 0    25 - Vinayaka Layout  39.324657         25        West   75687.559355
# 1            2 - Aerocity  38.621582          2       North  124800.280922
# 2   3 - Chowdeshwari ward  38.597490          3       North  102396.516478
# 3  15 - Ramamurthy Nagara  38.432678         15        East   22700.859701
# 4    58 - Nagashettyhalli  37.427218         58       North   25813.225031
#
#    street_density          area  straightness  global_closeness  Unnamed: 0  \
# 0    29390.911807  2.575203e+06      0.722825          0.000769           0
# 1    12164.886655  1.025906e+07      0.644505          0.000296           1
# 2    15924.039220  6.430310e+06      0.681202          0.000380           2
# 3    28293.603033  8.023319e+05      0.697888          0.001307           3
# 4    27016.836493  9.554496e+05      0.666402          0.001277           4
#
#    ward_id_y Corporatio  closeness_local
# 0         25       West         0.000321
# 1          2      North         0.000146
# 2          3      North         0.000185
# 3         15       East         0.000882
# 4         58      North         0.000796

# %%
merged = merged[['ward_name', 'mean_lst', 'ward_id_x', 'Corporation', 'street_length', 'street_density', 'area', 'straightness', 'global_closeness', 'closeness_local']]
merged.head()
# Out:
#                 ward_name   mean_lst  ward_id_x Corporation  street_length  \
# 0    25 - Vinayaka Layout  39.324657         25        West   75687.559355
# 1            2 - Aerocity  38.621582          2       North  124800.280922
# 2   3 - Chowdeshwari ward  38.597490          3       North  102396.516478
# 3  15 - Ramamurthy Nagara  38.432678         15        East   22700.859701
# 4    58 - Nagashettyhalli  37.427218         58       North   25813.225031
#
#    street_density          area  straightness  global_closeness  \
# 0    29390.911807  2.575203e+06      0.722825          0.000769
# 1    12164.886655  1.025906e+07      0.644505          0.000296
# 2    15924.039220  6.430310e+06      0.681202          0.000380
# 3    28293.603033  8.023319e+05      0.697888          0.001307
# 4    27016.836493  9.554496e+05      0.666402          0.001277
#
#    closeness_local
# 0         0.000321
# 1         0.000146
# 2         0.000185
# 3         0.000882
# 4         0.000796

# %%
# Rename the columns
merged = merged.rename(columns={
    'ward_id_x': 'ward_id',
    #'closeness': 'global closeness',
    'closeness_local': 'local_closeness'
})
merged.head()
# Out:
#                 ward_name   mean_lst  ward_id Corporation  street_length  \
# 0    25 - Vinayaka Layout  39.324657       25        West   75687.559355
# 1            2 - Aerocity  38.621582        2       North  124800.280922
# 2   3 - Chowdeshwari ward  38.597490        3       North  102396.516478
# 3  15 - Ramamurthy Nagara  38.432678       15        East   22700.859701
# 4    58 - Nagashettyhalli  37.427218       58       North   25813.225031
#
#    street_density          area  straightness  global_closeness  \
# 0    29390.911807  2.575203e+06      0.722825          0.000769
# 1    12164.886655  1.025906e+07      0.644505          0.000296
# 2    15924.039220  6.430310e+06      0.681202          0.000380
# 3    28293.603033  8.023319e+05      0.697888          0.001307
# 4    27016.836493  9.554496e+05      0.666402          0.001277
#
#    local_closeness
# 0         0.000321
# 1         0.000146
# 2         0.000185
# 3         0.000882
# 4         0.000796

# %%
# x and y
x = merged["local_closeness"]
y = merged["mean_lst"]

# %%
# plot
# plt.figure(figsize=(7, 6))
# plt.scatter(x, y, alpha=0.6, label="Pixels")

# %%
fig_path = IMAGES_DIR / 'regression_bangalore_local_closeness.png'

# %%
# linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# regression line
x_line = np.linspace(x.min(), x.max(), 100)
y_line = intercept + slope * x_line

# plot
plt.figure(figsize=(7, 6))
plt.scatter(x, y, alpha=0.6, label="Wards")
plt.plot(x_line, y_line, color="red", label="Linear fit")

plt.xlabel("local closeness")
plt.ylabel("Land Surface Temperature (LST)")
plt.title("LST versus local closeness")
plt.legend()


# annotation


plt.text(
    0.05, 0.98,
    f"$R^2$ = {r_value**2:.2f}\np = {p_value:.2e}",
    transform=plt.gca().transAxes,
    verticalalignment="top"
)

plt.text(
    0.05, 0.90,
    f"$LST  = {intercept:.2f} + {slope:.2f}\\,local closeness$",
    transform=plt.gca().transAxes,
    verticalalignment="top"
)
plt.savefig(fig_path, dpi=300, bbox_inches='tight')
plt.show()

# %%
#define response variable
y = merged['mean_lst']
#define predictor variables
x = merged['local_closeness']
#add constant to predictor variables
x = sm.add_constant(x)
#fit linear regression model
model = sm.OLS(y, x).fit()
#view model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               mean_lst   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.425
# Date:                Thu, 22 Jan 2026   Prob (F-statistic):              0.233
# Time:                        23:32:50   Log-Likelihood:                -575.68
# No. Observations:                 369   AIC:                             1155.
# Df Residuals:                     367   BIC:                             1163.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              38.7561      0.105    367.697      0.000      38.549      38.963
# local_closeness   127.9055    107.139      1.194      0.233     -82.777     338.588
# ==============================================================================
# Omnibus:                        1.882   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.390   Jarque-Bera (JB):                1.968
# Skew:                           0.155   Prob(JB):                        0.374
# Kurtosis:                       2.820   Cond. No.                     1.78e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.78e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pearsonr(merged['local_closeness'], merged['mean_lst'])
# Out:
# PearsonRResult(statistic=np.float64(0.06219685856359984), pvalue=np.float64(0.23331487188213434))

# %%
merged
# Out:
#                    ward_name   mean_lst  ward_id Corporation  street_length  \
# 0       25 - Vinayaka Layout  39.324657       25        West   75687.559355
# 1               2 - Aerocity  38.621582        2       North  124800.280922
# 2      3 - Chowdeshwari ward  38.597490        3       North  102396.516478
# 3     15 - Ramamurthy Nagara  38.432678       15        East   22700.859701
# 4       58 - Nagashettyhalli  37.427218       58       North   25813.225031
# ..                       ...        ...      ...         ...            ...
# 364           56 - Gopalpura  39.079316       56     Central   35744.795749
# 365          57 - Cottonpete  40.597494       57     Central   26427.639618
# 366           54 - Binnypete  39.749570       54     Central   13460.033232
# 367    47 - IPD Salappa Ward  39.408972       47     Central   14754.219527
# 368  61 - Da.Ra. Bendre Ward  39.929599       61        West   14611.517091
#
#      street_density          area  straightness  global_closeness  \
# 0      29390.911807  2.575203e+06      0.722825          0.000769
# 1      12164.886655  1.025906e+07      0.644505          0.000296
# 2      15924.039220  6.430310e+06      0.681202          0.000380
# 3      28293.603033  8.023319e+05      0.697888          0.001307
# 4      27016.836493  9.554496e+05      0.666402          0.001277
# ..              ...           ...           ...               ...
# 364    28128.275219  1.270778e+06      0.668262          0.000881
# 365    27655.070003  9.556164e+05      0.747517          0.001330
# 366    28211.384851  4.771135e+05      0.592171          0.001074
# 367    29909.713090  4.932919e+05      0.714489          0.001231
# 368    27717.380110  5.271608e+05      0.775274          0.001559
#
#      local_closeness
# 0           0.000321
# 1           0.000146
# 2           0.000185
# 3           0.000882
# 4           0.000796
# ..               ...
# 364         0.000521
# 365         0.001096
# 366         0.001290
# 367         0.001219
# 368         0.001364
#
# [369 rows x 10 columns]

# %% [markdown]
# ## Correlation

# %%
vars_df = merged[[
    "mean_lst",
    "street_density",
    "straightness",
    "global_closeness",
    "local_closeness"
]].dropna()

# %%
corr = vars_df.corr(method="pearson")

# %%
corr_path_indices = IMAGES_DIR / 'corr_road_bangalore.png'
plt.figure(figsize=(7, 6))

sns.heatmap(
    corr,
    annot=True,
    fmt=".2f",
    cmap="RdBu_r",
    center=0,
    square=True,
    linewidths=0.5,
    cbar_kws={"label": "Correlation coefficient"}
)

plt.title("Correlation between LST and road characteristics")
plt.tight_layout()
plt.savefig(corr_path_indices, dpi=300, bbox_inches="tight")
plt.show()
